# %%
import os
import pandas as pd

# %%
os.chdir('D:\Pycharm')

# %%
# importing data:

cars_data = pd.read_csv('Toyota.csv',index_col = 0, na_values = ["??","????"])
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
# Instead of na_values = ["??"] we can also use cars_data.replace("??", np.NAN).

# %%
# Creating a copy of original data:

cars_data2 = cars_data.copy()

# %%
# Frequency Tables:
# pandas.crosstab(): 
# • To compute a simple cross-tabulation of one, two (or more) factors
# • By default computes a frequency table of the factors

pd.crosstab(index = cars_data2['FuelType'], columns = 'count', dropna = True)
# Out:
# col_0     count
# FuelType
# CNG          15
# Diesel      144
# Petrol     1177

# %%
# most cars have petrol as fuel type.

# %%
# Two-Way Tables
# To look at the frequency distribution of gearbox types with respect to different fuel types of the cars.
# 0- Manual gear box 
# 1- Automatic gearbox

pd.crosstab(index = cars_data['Automatic'], columns = cars_data['FuelType'], dropna = True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
# Two-way table - joint probability:
# Joint probability is the likelihood of two independent events happening at the same time.

pd.crosstab(index = cars_data2['Automatic'], columns = cars_data2['FuelType'], normalize = True, dropna = True)
# Out:
# FuelType        CNG    Diesel    Petrol
# Automatic
# 0          0.011228  0.107784  0.826347
# 1          0.000000  0.000000  0.054641

# %%
# Two-way table - marginal probability:
# Marginal probability is the probability of the occurrence of the single event.
# probability of cars having manual gear box when the fuel type are CNG or Diesel or Petrol is 0.95.

pd.crosstab(index = cars_data2['Automatic'], columns = cars_data2['FuelType'], normalize = True, margins = True, dropna = True)
# Out:
# FuelType        CNG    Diesel    Petrol       All
# Automatic
# 0          0.011228  0.107784  0.826347  0.945359
# 1          0.000000  0.000000  0.054641  0.054641
# All        0.011228  0.107784  0.880988  1.000000

# %%
# Two-way table - conditional probability:
# Conditional probability is the probability of an event ( A ), given that another event ( B ) has already occurred.
# Given the type of gear box, probability of different fuel type.
# Row sum = 1

pd.crosstab(index = cars_data2['Automatic'], columns = cars_data2['FuelType'], normalize = 'index', margins = True, dropna = True)
# Out:
# FuelType        CNG    Diesel    Petrol
# Automatic
# 0          0.011876  0.114014  0.874109
# 1          0.000000  0.000000  1.000000
# All        0.011228  0.107784  0.880988

# %%
# Conditional probability is the probability of an event ( A ), given that another event ( B ) has already occurred.
# column sum = 1

pd.crosstab(index = cars_data2['Automatic'], columns = cars_data2['FuelType'], normalize = 'columns', margins = True, dropna = True)
# Out:
# FuelType   CNG  Diesel    Petrol       All
# Automatic
# 0          1.0     1.0  0.937978  0.945359
# 1          0.0     0.0  0.062022  0.054641

# %%
# Data Grouping:
# Df.Groupby()

# Example: use the groupby function to find the average "price" of each car based on "body-style": 
# df[['price','body-style']].groupby(['body-style'],as_index= False).mean()

# %%
# Pandas method - Pivot():
# One variable displayed along the columns other variable displayed along the rows.

# Example of syntax: df.pivot(index = "x", columns = "y")

# %%
# Correlation: the strength of association between two variables.
# DataFrame.corr(self, method='pearson’).
# To compute pairwise correlation of columns excluding NA/null values.
# Excluding the categorical variables to find the Pearson’s correlation.

numerical_data = cars_data.select_dtypes(exclude = ['object'])

# %%
# Let’ s check the no. of variables available under numerical_data:

numerical_data.shape
# Out:
# (1436, 8)

# %%
# Correlation between numerical variables:

corr_matrix = numerical_data.corr()
corr_matrix
# Out:
#               Price       Age        KM        HP  MetColor  Automatic  \
# Price      1.000000 -0.878407 -0.574720  0.309902  0.112041   0.033081
# Age       -0.878407  1.000000  0.512735 -0.157904 -0.099659   0.032573
# KM        -0.574720  0.512735  1.000000 -0.335285 -0.093825  -0.081248
# HP         0.309902 -0.157904 -0.335285  1.000000  0.064749   0.013755
# MetColor   0.112041 -0.099659 -0.093825  0.064749  1.000000  -0.013973
# Automatic  0.033081  0.032573 -0.081248  0.013755 -0.013973   1.000000
# CC         0.165067 -0.120706  0.299993  0.053758  0.029189  -0.069321
# Weight     0.581198 -0.464299 -0.026271  0.086737  0.057142   0.057249
#
#                  CC    Weight
# Price      0.165067  0.581198
# Age       -0.120706 -0.464299
# KM         0.299993 -0.026271
# HP         0.053758  0.086737
# MetColor   0.029189  0.057142
# Automatic -0.069321  0.057249
# CC         1.000000  0.651450
# Weight     0.651450  1.000000

# %%
# To chech the dependency of categorical data we cant use correlation instead we have to use chi-square test using scipy library.

# %%
# to rename a column in a data frame:
# Data_frame.rename(columns = {"old_name" : "new_name"}, inplace = True)

# %%
# pd.get_dummies(Data_Frame["column_name"])
# This converts categorical values to dummie variablies( 0 or 1).

# %%
# Object data type means - strings
# Category data type means the columns which have categories - Example - column Fuel_Type has category data types like: petrol, diesel, gas, etc.

# we can summarize the categorical data using value_counts() method.
